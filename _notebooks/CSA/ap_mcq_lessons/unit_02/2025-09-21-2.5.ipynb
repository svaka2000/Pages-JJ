// %% [raw]
// ---
// layout: post
// title: Compound Boolean Expressions
// categories: [Java, Boolean Expressions]
// lesson_language: Java
// lesson_topic: Compound-Boolean-Expressions
// lesson_part: interactive
// lesson_type: lesson
// permalink: /csa/unit_02/2_5
// author: Nora, Soni, Avika
// ---

// %% [markdown]
// ## The Core Rule
//
// Combine simple boolean expressions with `&&`, `\|\|`, and `!` to test multiple conditions at once, always evaluated in a fixed order: `!` first, then `&&`, then `\|\|`.

// %%
public class QuickCheck {
    public static void main(String[] args) {
        int age = 17;
        boolean hasPermit = true;

        boolean canDriveWithSupervision = (age >= 15) && hasPermit;
        System.out.println(canDriveWithSupervision);   // true
    }
}

QuickCheck.main(null);

// %% [markdown]
// ## Compound Operators Reference
//
// | Operator | Meaning | CSA usage |
// |---|---|---|
// | `&&` | AND | True only when **both** sides are true |
// | `\|\|` | OR | True when **at least one** side is true |
// | `!` | NOT | Flips true to false and false to true |
// | `( )` | Grouping | Forces a specific evaluation order |

// %% [markdown]
// ## Precedence & Range-Check Grammar
//
// | Rule | Use |
// |---|---|
// | Precedence order | `!` evaluates before `&&`, which evaluates before `\|\|` |
// | Range check | Combine two comparisons with `&&` to test "between" (e.g. `x >= 0 && x <= 10`) |
// | Either-or check | Combine two comparisons with `\|\|` to test "any of these" |
// | Parentheses | Use them to force your intended grouping instead of relying on default precedence |

// %% [markdown]
// -----
//
// ## 1. LxD Cycle Process
//
// **Empathize:** I noticed a lot of students write compound conditions like `age >= 13 && <= 19` (missing the second variable) or `score > 90 || score > 80 && passed` without parentheses, and get confused when the result doesn't match what they expected. They don't yet have a mental model for how Java actually groups `&&` and `\|\|` together.
//
// **Define:**
//
// - **POV:** AP CSA students need a reliable way to combine multiple conditions because writing them without understanding precedence produces bugs that are hard to trace.
// - **Learning Goal:** Students will correctly combine boolean expressions using `&&`, `\|\|`, and `!`, and will use parentheses to control evaluation order instead of relying on default precedence.
//
// **Ideate:**
//
// - **HMW Question:** How might we get students to always double-check precedence instead of assuming left-to-right reading order?
// - **Activity:** Given a compound expression with no parentheses, students first predict how Java groups it, then add parentheses to make their intended grouping explicit and check the output matches.
//
// **Prototype & Test:** I ran this with my project team. They mixed up range checks and either-or checks when I combined both patterns in one example, so I split range checks and either-or checks into two separate, clearly labeled code examples (documented below).

// %% [markdown]
// -----
//
// ## 2. Lesson Plan
//
// **Learning Objective:** By the end of this lesson, you will be able to combine boolean expressions using `&&`, `\|\|`, and `!`, and correctly predict how Java evaluates a compound expression based on operator precedence.
//
// **Success Criteria:** You can write a compound boolean expression for a given rule (a range, an either-or condition, or a negated condition) and correctly predict its result without running the code first.

// %% [markdown]
// ### Tech Talk (3 minutes)
//
// A single comparison can only ask one question. Compound expressions let you ask several questions at once and combine the answers.
//
// - **The Rule:** `!` runs first, then `&&`, then `\|\|`. When in doubt, add parentheses.
// - ✅ **Do this:** `(age >= 13) && (age <= 19)`
// - ❌ **Don't do this:** `age >= 13 && <= 19` (this isn't even valid Java, but it's a common typo pattern)
//
// Why do we do this? The AP exam frequently gives you a compound expression with no parentheses and asks you to trace through it using precedence rules alone. Getting the order wrong is one of the most common exam mistakes.

// %% [markdown]
// ### Code Examples
//
// #### A. Simple: Combining Two Conditions with AND

// %%
public class RangeCheck {
    public static void main(String[] args) {
        int score = 85;
        boolean isBGrade = (score >= 80) && (score < 90);
        System.out.println(isBGrade);   // true
    }
}

RangeCheck.main(null);

// %% [markdown]
// #### B. Intermediate: Combining Conditions with OR

// %%
public class EitherOrCheck {
    public static void main(String[] args) {
        String day = "Saturday";
        boolean isWeekend = day.equals("Saturday") || day.equals("Sunday");
        System.out.println(isWeekend);   // true

        int temperature = 102;
        boolean needsAttention = temperature < 95 || temperature > 100;
        System.out.println(needsAttention);   // true
    }
}

EitherOrCheck.main(null);

// %% [markdown]
// #### C. Complex: Precedence Without Parentheses

// %%
public class PrecedenceDemo {
    public static void main(String[] args) {
        boolean a = true, b = false, c = false;

        // No parentheses: && binds tighter than ||
        // Java reads this as: a || (b && c)
        boolean noParens = a || b && c;
        System.out.println("a || b && c -> " + noParens);

        // Explicit grouping showing the same evaluation order
        boolean explicit = a || (b && c);
        System.out.println("a || (b && c) -> " + explicit);

        // A different grouping changes the result
        boolean differentGrouping = (a || b) && c;
        System.out.println("(a || b) && c -> " + differentGrouping);
    }
}

PrecedenceDemo.main(null);

// %% [markdown]
// -----
//
// ## 3. Hacks & Practice Tasks
//
// ### Prepare Your Submission IPYNB
//
// Complete this quick-start flow so you can begin in about 2 minutes.
//
// 1. Create a new notebook in your portfolio homework area: `_notebooks/homework`.
// 2. Add one markdown cell at the top with the frontmatter below.
// 3. Add code cells for Popcorn and Homework. Keep the `UI_RUNNER` comment line in each code cell.
// 4. Run each cell and verify the printed output before submitting.

// %% [markdown]
// ```
// ---
// layout: post
// title: Compound Boolean Expressions HW
// categories: [Java]
// lesson_language: Java
// lesson_topic: Compound Boolean Expressions HW
// lesson_part: interactive
// lesson_type: lesson
// permalink: /csa/unit_02/2_5/homework
// author: githubID
// ---
// ```

// %% [markdown]
// ### Submission Safety Rules (Read First)
//
// **[!IMPORTANT]** To avoid grading errors, follow these rules exactly:
//
// - Submit only your final Java code for each hack.
// - Do not skip parentheses where the task asks you to make grouping explicit.
// - Keep the `UI_RUNNER` comment line in each submission cell.
// - Use only boolean variables, relational operators, and `&&`, `||`, `!` for this lesson.
// - Your program must print a result for every condition the task asks you to test.

// %% [markdown]
// ### Popcorn Hack (In-Class)
//
// **[!TIP]** 2-minute challenge: predict, then run, then paste only your corrected code in chat.
//
// Task: Predict by hand whether a student with `grade = 88` qualifies for honor roll, defined as a grade of at least 90, OR a grade of at least 80 AND perfect attendance. Then complete the code below to check your prediction.

// %%
// UI_RUNNER: Compound Popcorn Base

public class PopcornCheck {
    public static void main(String[] args) {
        int grade = 88;
        boolean perfectAttendance = true;

        // TODO: write honorRoll using grade, perfectAttendance, &&, ||, and parentheses
        // boolean honorRoll = ...
        // System.out.println(honorRoll);
    }
}

PopcornCheck.main(null);

// %% [markdown]
// Expected direction: your expression should use parentheses to make the intended grouping unambiguous, not rely on default precedence.

// %% [markdown]
// ### Homework Hack
//
// Task: Write a complete Java program that determines ride eligibility for an amusement park ride. A rider qualifies if they are at least 48 inches tall AND at least 8 years old, OR they are accompanied by an adult. Test your program with at least three different combinations of height, age, and adult-accompaniment, printing the result for each.

// %%
// UI_RUNNER: Compound Homework Base

public class HomeworkCheck {
    public static void main(String[] args) {
        // TODO: declare height, age, and accompaniedByAdult for test case 1
        // TODO: write the eligibility expression using && , ||, and parentheses
        // TODO: print the result

        // TODO: repeat for at least two more test cases with different values
    }
}

HomeworkCheck.main(null);

// %% [markdown]
// -----
//
// ## 4. Grading Plan (1 Point Total)
//
// ### Classroom Rubric
//
// - **0.2 points: Popcorn completion** — Student submitted a working, parenthesized expression and kept the `UI_RUNNER` comment.
// - **0.8 points: Homework completion**
//   - **0.4 correctness:** The eligibility expression correctly combines `&&` and `\|\|` with parentheses matching the stated rule.
//   - **0.3 completeness:** At least three distinct test cases are run and printed.
//   - **0.1 clarity:** Parentheses are used to make grouping explicit rather than relying on default precedence.
//
// ### Quick Validation Checklist
//
// - Present: `UI_RUNNER` comment line in each submission cell.
// - Absent: hardcoded `true`/`false` answers instead of an actual expression.
// - Present: at least one `&&`, one `\|\|`, and explicit parentheses somewhere in the homework.
// - Present: three or more distinct test cases with printed results.

// %% [markdown]
// -----
//
// ## 5. Lesson Revisions & Feedback Evidence
//
// **Feedback Received:** During my peer practice run, my teammate mixed up the range-check pattern and the either-or pattern when I combined both into a single code example, since both use similar-looking comparisons.
//
// **Revision Made:** I split the range-check example and the either-or example into two separate, clearly labeled code cells (A and B) so students can compare the patterns without conflating them, and reserved the precedence-without-parentheses trap for a dedicated third example (C).

// %% [markdown]
// -----
//
// ## Submit Assignment
//
// ### Once you've finished the lesson and run/written all the hacks in a notebook, submit here
//
// <a href="{{ site.baseurl }}/csa/unit_02/2_5/homework">Homework</a>
//
// [Submission Form](REPLACE_WITH_YOUR_SUBMISSION_FORM_LINK)
//
// Need to update a submission later? Open the submissions dashboard.

// %% [markdown]
// -----
//
// ## Resources
//
// [AP classroom](https://apstudents.collegeboard.org/courses/ap-computer-science-a)
//
// [CED Compound Boolean Expressions section](https://apcentral.collegeboard.org/media/pdf/ap-computer-science-a-course-and-exam-description.pdf)
