# %% [raw]
# ---
# layout: post
# courses: { csa: {week: 2} }
# categories: [Java, Comparing-Boolean-Expressions]
# lesson_language: Java
# lesson_topic: Comparing-Boolean-Expressions
# lesson_part: interactive
# lesson_type: lesson
# toc: true
# title: Comparing Boolean Expressions
# menu: nav/csa_units/csaunit2.html
# permalink: /csa/unit_02/2_6
# authors: Akshaj Gurugubelli
# ---

# %% [markdown]
# ## The Core Rule
#
# Two boolean expressions are equivalent only when they produce the **same result for every possible input**, confirmed with a full truth table, never a single test case.

# %%
public class QuickCheck {
    public static void main(String[] args) {
        boolean a = true, b = false;
        System.out.println(!(a && b));   // true
        System.out.println(!a || !b);    // true — matches
    }
}

QuickCheck.main(null);

# %% [markdown]
# ## Boolean Operators Reference
#
# | Operator | Meaning | CSA usage |
# |---|---|---|
# | `==` | Equal to | Compare primitive values |
# | `!=` | Not equal to | Compare primitive values |
# | `&&` | Logical AND | True only if both sides are true |
# | `\|\|` | Logical OR | True if at least one side is true |
# | `!` | Logical NOT | Flips true to false and false to true |

# %% [markdown]
# ## Equivalence & De Morgan's Grammar
#
# | Rule | Use |
# |---|---|
# | Equivalent expressions | Two expressions that match on **every row** of the truth table |
# | Truth table | A chart testing every possible T/F input combination |
# | De Morgan's Law 1 | `!(a && b)` is equivalent to `!a \|\| !b` |
# | De Morgan's Law 2 | `!(a \|\| b)` is equivalent to `!a && !b` |
# | Short-circuit evaluation | Java skips checking the right side once the result is already known |

# %% [markdown]
# -----
#
# ## 1. LxD Cycle Process
#
# **Empathize:** I noticed a lot of students check whether two boolean expressions are equivalent by testing just one case (like `a = true, b = true`) and assuming that if it matches, the expressions are always equal. This creates a shaky mental model and leads to real mistakes on the AP exam's equivalence questions, where three of four answer choices "look" equivalent but fail on exactly one row.
#
# **Define:**
#
# - **POV:** AP CSA students need a reliable method to compare boolean expressions because testing a single case creates false confidence and leads to wrong answers.
# - **Learning Goal:** Students will determine whether two boolean expressions are equivalent by building and comparing complete truth tables, and will apply De Morgan's Laws to rewrite negated compound expressions.
#
# **Ideate:**
#
# - **HMW Question:** How might we get students to build a full truth table instead of testing just one case?
# - **Activity:** Given two boolean expressions side by side, students predict the truth table by hand, then verify it with a Java program that loops through every T/F combination.
#
# **Prototype & Test:** I ran this activity with my project team. They found working out a full 3-variable, 8-row truth table by hand too slow for a 2-minute in-class task, so I moved the 3-variable version to homework and kept the in-class hack to a simpler 2-variable check (documented below).

# %% [markdown]
# -----
#
# ## 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to determine whether two boolean expressions are equivalent using a truth table, and rewrite negated compound expressions using De Morgan's Laws.
#
# **Success Criteria:** You can build a complete truth table for a boolean expression, compare it row-by-row against another expression, and correctly identify whether they are equivalent, before ever running any code.

# %% [markdown]
# ### Tech Talk (3 minutes)
#
# We are comparing boolean expressions. This means you can't plug in one value and call it done. You need to test **every possible combination** of inputs and confirm the results always match.
#
# - **The Rule:** Two expressions are equivalent only if they agree on every single row of the truth table.
# - ✅ **Do this:** build all 4 rows for a 2-variable expression before concluding equivalence
# - ❌ **Don't do this:** test only `a=true, b=true` and assume the rest follow
#
# Why do we do this? The AP exam tests equivalence with multiple-choice questions designed so a partial check picks the wrong answer. A full truth table is the only reliable proof.

# %% [markdown]
# ### Code Examples
#
# #### A. Simple: Testing One Boolean Expression

# %%
public class BooleanBasics {
    public static void main(String[] args) {
        boolean a = true;
        boolean b = false;
        System.out.println(a && b);   // false
        System.out.println(a || b);   // true
        System.out.println(!a);       // false
    }
}

BooleanBasics.main(null);

# %% [markdown]
# #### B. Intermediate: Comparing Two Expressions Across All Combinations

# %%
public class CompareTwo {
    public static void main(String[] args) {
        boolean[] values = {true, false};
        for (boolean a : values) {
            for (boolean b : values) {
                boolean left = !(a && b);
                boolean right = !a || !b;
                System.out.println("a=" + a + " b=" + b + " -> " + left + " | " + right);
            }
        }
    }
}

CompareTwo.main(null);

# %% [markdown]
# #### C. Complex: Three-Variable Equivalence Check

# %%
public class ThreeVariableCheck {
    public static void main(String[] args) {
        boolean[] values = {true, false};
        for (boolean a : values) {
            for (boolean b : values) {
                for (boolean c : values) {
                    boolean left = a && (b || c);
                    boolean right = (a && b) || (a && c);
                    System.out.println("a=" + a + " b=" + b + " c=" + c +
                        " -> " + left + " | " + right);
                }
            }
        }
    }
}

ThreeVariableCheck.main(null);

# %% [markdown]
# -----
#
# ## 3. Hacks & Practice Tasks
#
# ### Prepare Your Submission IPYNB
#
# Complete this quick-start flow so you can begin in about 2 minutes.
#
# 1. Create a new notebook in your portfolio homework area: `_notebooks/homework`.
# 2. Add one markdown cell at the top with the frontmatter below.
# 3. Add code cells for Popcorn and Homework. Keep the `UI_RUNNER` comment line in each code cell.
# 4. Run each cell and verify the printed output before submitting.

# %% [markdown]
# ### Submission Safety Rules (Read First)
#
# **[!IMPORTANT]** To avoid grading errors, follow these rules exactly:
#
# - Submit only your final Java code for each hack.
# - Do not hardcode the answer as a comment instead of writing the loop.
# - Keep the `UI_RUNNER` comment line in each submission cell.
# - Use only boolean variables, relational operators, and `&&`, `||`, `!` for this lesson.
# - Your program must print a result for **every** row of the truth table, not just one.

# %% [markdown]
# ### Popcorn Hack (In-Class)
#
# **[!TIP]** 2-minute challenge: predict, then run, then paste only your corrected code in chat.
#
# Task: Predict by hand whether `!(a || b)` is equivalent to `!a && !b` for a 2-variable truth table. Then complete the loop below to check your prediction.

# %%
// UI_RUNNER: Boolean Popcorn Base

public class PopcornCheck {
    public static void main(String[] args) {
        // TODO: loop through true/false for a and b
        // TODO: compare !(a || b) to !a && !b
    }
}

PopcornCheck.main(null);

# %% [markdown]
# Expected direction: your printed output should show 4 rows, and both sides should match on every row.

# %% [markdown]
# ### Homework Hack
#
# Task: Write a complete Java program that tests whether `a && (b || c)` is equivalent to `(a && b) || (a && c)` across all 8 combinations of three boolean variables. Print each row's inputs and both results side by side, then state in a comment at the bottom whether the two expressions are equivalent.

# %%
// UI_RUNNER: Boolean Homework Base

public class HomeworkCheck {
    public static void main(String[] args) {
        // TODO: loop through true/false for a, b, and c
        // TODO: compute a && (b || c)
        // TODO: compute (a && b) || (a && c)
        // TODO: print both results for every combination
    }
}

HomeworkCheck.main(null);

# %% [markdown]
# -----
#
# ## 4. Grading Plan (1 Point Total)
#
# ### Classroom Rubric
#
# - **0.2 points: Popcorn completion** — Student submitted a working loop that tests all 4 rows and kept the `UI_RUNNER` comment.
# - **0.8 points: Homework completion**
#   - **0.4 correctness:** Program correctly computes both expressions for all 8 rows.
#   - **0.3 completeness:** All 8 combinations are printed, not a subset.
#   - **0.1 conclusion:** Comment at the bottom correctly states whether the expressions are equivalent, matching the printed output.
#
# ### Quick Validation Checklist
#
# - Present: `UI_RUNNER` comment line in each submission cell.
# - Absent: hardcoded `true`/`false` answers instead of an actual loop.
# - Present: nested loops covering every combination of the boolean variables.
# - Present: a final comment stating equivalent or not equivalent, matching the actual printed output.

# %% [markdown]
# -----
#
# ## 5. Lesson Revisions & Feedback Evidence
#
# **Feedback Received:** During my peer practice run, my teammate said working out all 8 rows of a 3-variable truth table by hand for the Popcorn Hack ate up the whole 2-minute window before they even got to write code.
#
# **Revision Made:** I moved the 3-variable truth table to the Homework Hack and kept the in-class Popcorn Hack to a simpler 2-variable check, so students still practice the core loop pattern quickly without running out of time.

# %% [markdown]
# -----
#
# ## Submit Assignment
#
# ### Once you've finished the lesson and run/written all the hacks in a notebook, submit here
#
# <a href="{{ site.baseurl }}/csa/unit_02/2_6/homework">Homework</a>
#
# [Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeREIolJ4X8lqJ8kn0BaOM97lZHL5iM6Jp9wjN_oUKk8MQn7g/viewform?usp=dialog)
#
# Need to update a submission later? Open the submissions dashboard.

# %% [markdown]
# -----
#
# ## Resources
#
# [AP classroom](https://apstudents.collegeboard.org/courses/ap-computer-science-a)
#
# [CED Boolean Expressions section](https://apcentral.collegeboard.org/media/pdf/ap-computer-science-a-course-and-exam-description.pdf)
